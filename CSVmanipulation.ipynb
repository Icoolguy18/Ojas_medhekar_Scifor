# %%
  #Q1
import pandas as pd
df = pd.read_csv(r"/content/csv_assignement.csv")
df.head()
# Out:
#    index Name Class  Age
# 0      1    a     a   10
# 1      2    b     b   12
# 2      3    c     a   11
# 3      4    d     b   12
# 4      5    e     c   11

# %%
#Q2
import numpy as np
sales_data = {'Q1': [300, 400, 500], 'Q2': [350, 450, 550], 'Q3': [320, 420, 520], 'Q4': [310, 410, 510]}
sales_df = pd.DataFrame(sales_data, index=['Product A', 'Product B', 'Product C'])
print(sales_df)
# Out:
#             Q1   Q2   Q3   Q4
# Product A  300  350  320  310
# Product B  400  450  420  410
# Product C  500  550  520  510

# %%
#Q3
zone_a = {'Sales': 50000, 'Profit': 2000}
zone_b = {'Sales': 60000, 'Profit': 2500}
zone_c = {'Sales': 55000, 'Profit': 2200}
zone_d = {'Sales': 62000, 'Profit': 2700}

zone_data = [zone_a, zone_b, zone_c, zone_d]
zones = ['zone a', 'zone b', 'zone c', 'zone d']

sales_df = pd.DataFrame(zone_data, index = zones)

print(sales_df)
# Out:
#         Sales  Profit
# zone a  50000    2000
# zone b  60000    2500
# zone c  55000    2200
# zone d  62000    2700

# %%
#Q$
people_data = {'Name': ['Rahul', 'Yash', 'Aditya'], 'Weight': [65, 70, 72], 'Age': [25, 30, 35]}

people_df = pd.DataFrame(people_data)
print(people_df)
# Out:
#      Name  Weight  Age
# 0   Rahul      65   25
# 1    Yash      70   30
# 2  Aditya      72   35

# %%
data_edu = {
            'faculty': ['A', 'B', 'C', 'D', 'E','F','G','H','I','K'],
            'subject': ['Science', 'Mathematics','English','English','Science','Mathematics','Mathematics','Mathematics','Science','English'],
            'strenght': [12,34,55,12,56,76,43,45,66,30],
            'class': ['S1','M1','E1','E2','S2','M2','M3','M4','S3','E3'],
            'lab score': [80,88,89,90,92,99,91,89,82,89]
}
df = pd.DataFrame(data_edu)
df
# Out:
#   faculty      subject  strenght class  lab score
# 0       A      Science        12    S1         80
# 1       B  Mathematics        34    M1         88
# 2       C      English        55    E1         89
# 3       D      English        12    E2         90
# 4       E      Science        56    S2         92
# 5       F  Mathematics        76    M2         99
# 6       G  Mathematics        43    M3         91
# 7       H  Mathematics        45    M4         89
# 8       I      Science        66    S3         82
# 9       K      English        30    E3         89

# %%
df.insert(5, 'active days', [30,33,35,36,32,31,30,33,37,40])
df
# Out:
#   faculty      subject  strenght class  lab score  active days
# 0       A      Science        12    S1         80           30
# 1       B  Mathematics        34    M1         88           33
# 2       C      English        55    E1         89           35
# 3       D      English        12    E2         90           36
# 4       E      Science        56    S2         92           32
# 5       F  Mathematics        76    M2         99           31
# 6       G  Mathematics        43    M3         91           30
# 7       H  Mathematics        45    M4         89           33
# 8       I      Science        66    S3         82           37
# 9       K      English        30    E3         89           40

# %%
df.drop('active days', axis = 1)
# Out:
#   faculty      subject  strenght class  lab score
# 0       A      Science        12    S1         80
# 1       B  Mathematics        34    M1         88
# 2       C      English        55    E1         89
# 3       D      English        12    E2         90
# 4       E      Science        56    S2         92
# 5       F  Mathematics        76    M2         99
# 6       G  Mathematics        43    M3         91
# 7       H  Mathematics        45    M4         89
# 8       I      Science        66    S3         82
# 9       K      English        30    E3         89

# %%
df.transpose()
# Out:
#                    0            1        2        3        4            5  \
# faculty            A            B        C        D        E            F
# subject      Science  Mathematics  English  English  Science  Mathematics
# strenght          12           34       55       12       56           76
# class             S1           M1       E1       E2       S2           M2
# lab score         80           88       89       90       92           99
# active days       30           33       35       36       32           31
#
#                        6            7        8        9
# faculty                G            H        I        K
# subject      Mathematics  Mathematics  Science  English
# strenght              43           45       66       30
# class                 M3           M4       S3       E3
# lab score             91           89       82       89
# active days           30           33       37       40

# %%
df.iloc[1:3,2:5]
# Out:
#    strenght class  lab score
# 1        34    M1         88
# 2        55    E1         89
